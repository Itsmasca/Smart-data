# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
from sklearn import linear_model 
from sklearn.metrics import mean_sqared_error, r2_score
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 5
#       3 import matplotlib.pyplot as plt
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 5 from sklearn import linear_model
#       6 from sklearn.metrics import mean_sqared_error, r2_score
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
data = pd.read_csv("")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data = pd.read_csv("")
#
# NameError: name 'pd' is not defined

# %%
data.shape

# %%
data.head

# %%
x_train = np.array(data['llamadas']).reshape(-1,1)
y_train = np.array(data['ventas'])

# %%
r = linear_model.linearRegresion()
r.fit(X_train, y_train)
y_pred = r.predict(X_train)
print(f"correlacion: {r.coef_}")
print(f"Interseccion: {r.intercept_}")
print(f"Error cuadratico: {mean_squared_error(y_train, y_pred)}")
print(f"Varianza: {r2_score(y_train, y_pred)}")
